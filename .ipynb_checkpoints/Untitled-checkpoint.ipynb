# %%
# coding: utf-8

# In[38]:

# from retrying import retry
import time
import requests, bs4
import datetime
import json
token = "506337865:AAELIzsWuRF2Vw7HgcsHjATQd1SvH31Hr30"
# @retry
def Wether():
    w = requests.get('https://yandex.ru/pogoda/moscow') 
    w = w.text 
    w = bs4.BeautifulSoup(w, 'html.parser') 
    w = w.find('span', class_="temp__value").next_element
    return w
def Time():
    return time.strftime("%M")
# @retry
def Btc():
    b = requests.get("https://bittrex.com/api/v1.1/public/getmarketsummary?market=USD-BTC")
    b = b.json()
    b = b['result'][0]['Last']
    return b
pull = {"Hello":"Hello Billionaire", "Hi":"hey", "Btc":Btc()}
datep = 0
#@retry
def getupdates():
    s = requests.get("https://api.telegram.org/bot" + token +"/getupdates", proxies=dict(http='socks5://telegram:telegram@hvmas.tgproxy.me:1080', https='socks5://telegram:telegram@hvmas.tgproxy.me:1080'))
    s = s.json()
    s = s['result'][-1]['message']
    date = s['date']
    chat_id = s['chat']['id']
    first_name = s['from']['first_name']
    s = s['text']
    return s, chat_id, date, first_name
# @retry
def sendm():
    m = requests.get("https://api.telegram.org/bot" + token +"/sendMessage?chat_id=" + str(chat_id) + "&" + "text=" + str(textm), proxies=dict(http='socks5://telegram:telegram@hvmas.tgproxy.me:1080', https='socks5://telegram:telegram@hvmas.tgproxy.me:1080'))

while True:
    
    s, chat_id, date, first_name = getupdates()
    min = time.strftime("%M")

    if min=="00":
        textm = "new hour!"
        sendm()
        time.sleep(60)
    if date!=datep:          
        if s=="Btc":
            textm = Btc()                
        elif s=="Wether":
            textm = Wether()
        elif s=="Time":
            textm = Time()                
            
        elif s=="Hello":
            textm = "Hi, Billionaire!"                
        

        else:
             textm = "Hi, " + first_name + ". Press the command. I know following commands: Btc, Time, Hello, Wether"
        sendm()
        datep = date
        
    
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6b8fe9031c15> in <module>()
#      43 while True:
#      44
# ---> 45     s, chat_id, date, first_name = getupdates()
#      46     min = time.strftime("%M")
#      47
#
# <ipython-input-7-6b8fe9031c15> in getupdates()
#      29 #@retry
#      30 def getupdates():
# ---> 31     s = requests.get("https://api.telegram.org/bot" + token +"/getupdates", proxies=dict(http='socks5://telegram:telegram@hvmas.tgproxy.me:1080', https='socks5://telegram:telegram@hvmas.tgproxy.me:1080'))
#      32     s = s.json()
#      33     s = s['result'][-1]['message']
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/socks.py in _new_conn(self)
#      86                 proxy_rdns=self._socks_options['rdns'],
#      87                 timeout=self.timeout,
# ---> 88                 **extra_kw
#      89             )
#      90
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in create_connection(dest_pair, proxy_type, proxy_addr, proxy_port, proxy_rdns, proxy_username, proxy_password, timeout, source_address, socket_options)
#     227                 sock.bind(source_address)
#     228
# --> 229             sock.connect((remote_host, remote_port))
#     230             return sock
#     231
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in wrapper(*args, **kwargs)
#      94             if _is_blocking == 0:
#      95                 self.setblocking(True)
# ---> 96             return function(*args, **kwargs)
#      97         except Exception as e:
#      98             raise
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in connect(self, dest_pair)
#     811                 # Calls negotiate_{SOCKS4, SOCKS5, HTTP}
#     812                 negotiate = self._proxy_negotiators[proxy_type]
# --> 813                 negotiate(self, dest_addr, dest_port)
#     814             except socket.error as error:
#     815                 # Wrap socket errors
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in _negotiate_SOCKS5(self, *dest_addr)
#     475         CONNECT = b"\x01"
#     476         self.proxy_peername, self.proxy_sockname = self._SOCKS5_request(self,
# --> 477             CONNECT, dest_addr)
#     478
#     479     def _SOCKS5_request(self, conn, cmd, dst):
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in _SOCKS5_request(self, conn, cmd, dst)
#     518                              + password)
#     519                 writer.flush()
# --> 520                 auth_status = self._readall(reader, 2)
#     521                 if auth_status[0:1] != b"\x01":
#     522                     # Bad response
#
# ~/anaconda3/lib/python3.6/site-packages/socks.py in _readall(self, file, count)
#     302         data = b""
#     303         while len(data) < count:
# --> 304             d = file.read(count - len(data))
#     305             if not d:
#     306                 raise GeneralProxyError("Connection closed unexpectedly")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
